# %% [markdown]
# # Beta REG
#
# https://gist.github.com/brentp/089c7d6d69d78d26437f

# %%
library(Metrics)
library(rpart)

grade_train = structure(list(final_grade = c(3, 3, 5, 5, 3, 9.5, 7.5, 4.5, 
                                             6, 7, 5.5, 7, 2.5, 7.5, 8, 6, 4, 4, 5.5, 7.5, 5.5, 6, 8.5, 8, 
                                             6, 3, 7.5, 6.5, 6, 5.5, 4.5, 5.5, 10, 3.5, 6.5, 5, 5.5, 6.5, 
                                             5, 7.5, 7.5, 4.5, 8, 5.5, 4.5, 4.5, 5, 7.5, 6, 4, 7.5, 2.5, 7, 
                                             5.5, 5.5, 6, 3, 7.5, 4, 7, 5, 3.5, 4, 9, 3, 7.5, 5, 4, 2.5, 8.5, 
                                             7, 9, 5.5, 4, 9, 8, 6.5, 9.5, 4.5, 8, 6.5, 4, 6.5, 7.5, 6.5, 
                                             6.5, 6, 5.5, 4.5, 0, 9, 0, 0, 6, 5.5, 0, 0, 0, 7.5, 0, 4.5, 5.5, 
                                             6.5, 5.5, 0, 0, 0, 7, 5, 0, 6, 4, 6.5, 5, 7.5, 6, 0, 0, 6, 5, 
                                             8, 7, 0, 0, 4.5, 5.5, 4.5, 4, 6, 4, 5.5, 5, 4.5, 4, 7, 7.5, 8, 
                                             9, 8, 5, 5, 3, 5.5, 4.5, 3.5, 6.5, 5, 6.5, 7.5, 2, 5, 3, 0, 8.5, 
                                             6.5, 3.5, 7.5, 6, 4.5, 7, 5.5, 4.5, 6.5, 3, 5, 6.5, 6, 5.5, 0, 
                                             6, 6, 6, 0, 9, 6.5, 4, 2.5, 4, 4, 6, 4, 6.5, 5.5, 7, 9, 4, 6, 
                                             8.5, 5, 5, 0, 4.5, 7, 5.5, 7, 5, 6, 4.5, 4.5, 4, 4, 5, 5, 5.5, 
                                             5.5, 9.5, 6, 7, 7.5, 5.5, 7.5, 9, 7, 5.5, 0, 4, 7, 5.5, 5, 7, 
                                             9, 6.5, 9, 6, 5, 0, 6.5, 6.5, 5.5, 0, 4.5, 5.5, 6.5, 4.5, 5.5, 
                                             4.5, 7, 0, 0, 7.5, 6.5, 0, 8.5, 0, 7.5, 0, 5, 7, 8, 4.5, 7.5, 
                                             4, 6.5, 4, 4.5, 5.5, 8, 6.5, 6, 7.5, 6, 6.5, 5, 5.5, 4.5, 6, 
                                             2.5, 9.5, 5, 7.5, 7.5, 5, 7, 3.5, 5, 2.5, 5, 4, 4.5, 8, 5, 4.5
), age = c(18L, 17L, 15L, 16L, 17L, 15L, 15L, 15L, 15L, 15L, 
           15L, 16L, 17L, 15L, 16L, 16L, 15L, 16L, 15L, 15L, 16L, 15L, 15L, 
           15L, 15L, 15L, 16L, 15L, 15L, 15L, 16L, 16L, 16L, 15L, 16L, 15L, 
           15L, 15L, 16L, 15L, 15L, 15L, 16L, 16L, 16L, 16L, 15L, 16L, 15L, 
           15L, 16L, 15L, 16L, 16L, 16L, 15L, 15L, 15L, 15L, 15L, 16L, 16L, 
           16L, 15L, 16L, 16L, 16L, 16L, 16L, 16L, 15L, 15L, 15L, 15L, 16L, 
           16L, 16L, 15L, 15L, 16L, 16L, 17L, 15L, 15L, 16L, 16L, 15L, 15L, 
           19L, 18L, 16L, 15L, 15L, 17L, 16L, 15L, 17L, 16L, 15L, 15L, 16L, 
           15L, 16L, 15L, 15L, 16L, 18L, 16L, 15L, 19L, 17L, 15L, 17L, 18L, 
           16L, 16L, 17L, 16L, 16L, 16L, 16L, 16L, 16L, 16L, 16L, 16L, 16L, 
           16L, 16L, 17L, 17L, 17L, 17L, 17L, 16L, 17L, 17L, 17L, 16L, 16L, 
           17L, 17L, 16L, 17L, 16L, 16L, 16L, 17L, 17L, 17L, 17L, 17L, 17L, 
           16L, 18L, 18L, 17L, 17L, 18L, 17L, 17L, 17L, 16L, 16L, 16L, 17L, 
           16L, 17L, 18L, 17L, 17L, 16L, 18L, 16L, 17L, 22L, 18L, 18L, 16L, 
           17L, 17L, 17L, 19L, 18L, 18L, 18L, 18L, 18L, 17L, 18L, 18L, 19L, 
           18L, 18L, 17L, 17L, 17L, 18L, 18L, 18L, 17L, 17L, 18L, 17L, 17L, 
           18L, 17L, 18L, 18L, 18L, 17L, 17L, 18L, 17L, 19L, 18L, 18L, 18L, 
           17L, 17L, 17L, 19L, 20L, 19L, 19L, 19L, 19L, 19L, 19L, 18L, 18L, 
           18L, 17L, 17L, 17L, 17L, 17L, 18L, 18L, 17L, 19L, 17L, 18L, 18L, 
           18L, 17L, 18L, 18L, 18L, 18L, 17L, 19L, 17L, 19L, 18L, 17L, 18L, 
           18L, 18L, 17L, 17L, 18L, 18L, 18L, 19L, 18L, 17L, 18L, 18L, 20L, 
           18L, 17L, 18L, 18L, 17L, 18L, 18L, 18L, 20L, 17L, 18L, 19L), 
address = structure(c(2L, 2L, 2L, 2L, 2L, 2L, 2L, 2L, 2L, 
                      2L, 2L, 2L, 2L, 2L, 2L, 2L, 1L, 2L, 2L, 2L, 2L, 2L, 2L, 1L, 
                      2L, 2L, 1L, 1L, 2L, 2L, 2L, 2L, 2L, 2L, 2L, 2L, 2L, 2L, 2L, 
                      2L, 2L, 2L, 2L, 2L, 2L, 2L, 2L, 2L, 2L, 1L, 2L, 1L, 2L, 2L, 
                      2L, 2L, 2L, 2L, 2L, 2L, 2L, 2L, 2L, 2L, 2L, 1L, 2L, 2L, 2L, 
                      2L, 2L, 2L, 2L, 2L, 2L, 2L, 2L, 2L, 1L, 2L, 2L, 1L, 2L, 2L, 
                      2L, 2L, 2L, 2L, 2L, 1L, 1L, 1L, 2L, 2L, 2L, 2L, 1L, 2L, 2L, 
                      2L, 2L, 2L, 2L, 2L, 2L, 2L, 2L, 2L, 1L, 2L, 2L, 1L, 1L, 1L, 
                      1L, 2L, 1L, 2L, 2L, 2L, 2L, 2L, 2L, 2L, 2L, 2L, 1L, 2L, 2L, 
                      2L, 2L, 1L, 2L, 2L, 2L, 2L, 2L, 2L, 2L, 2L, 2L, 1L, 1L, 2L, 
                      2L, 2L, 2L, 2L, 2L, 2L, 2L, 1L, 2L, 2L, 2L, 1L, 2L, 2L, 2L, 
                      2L, 1L, 2L, 2L, 2L, 2L, 2L, 2L, 1L, 2L, 2L, 1L, 2L, 2L, 2L, 
                      2L, 2L, 1L, 2L, 1L, 1L, 2L, 2L, 2L, 2L, 2L, 2L, 1L, 1L, 2L, 
                      2L, 1L, 2L, 2L, 2L, 1L, 2L, 2L, 1L, 2L, 2L, 2L, 2L, 2L, 2L, 
                      2L, 2L, 2L, 2L, 2L, 2L, 2L, 1L, 1L, 2L, 2L, 2L, 2L, 2L, 2L, 
                      2L, 2L, 2L, 2L, 1L, 2L, 2L, 2L, 2L, 1L, 2L, 2L, 2L, 2L, 2L, 
                      1L, 2L, 1L, 2L, 1L, 2L, 1L, 2L, 2L, 2L, 2L, 2L, 2L, 2L, 1L, 
                      2L, 2L, 1L, 2L, 1L, 2L, 2L, 2L, 1L, 1L, 2L, 1L, 2L, 2L, 1L, 
                      2L, 1L, 1L, 1L, 1L, 2L, 2L, 1L, 2L, 1L, 2L, 1L, 1L, 2L, 2L, 
                      2L, 1L, 2L), .Label = c("R", "U"), class = "factor"), studytime = c(2L, 
                                                                                          2L, 2L, 2L, 2L, 2L, 2L, 2L, 3L, 1L, 2L, 1L, 1L, 1L, 2L, 2L, 
                                                                                          3L, 1L, 1L, 1L, 2L, 2L, 2L, 2L, 2L, 1L, 3L, 1L, 1L, 1L, 2L, 
                                                                                          2L, 4L, 2L, 2L, 1L, 1L, 1L, 2L, 2L, 2L, 2L, 2L, 1L, 2L, 3L, 
                                                                                          2L, 2L, 4L, 2L, 4L, 2L, 1L, 2L, 4L, 1L, 2L, 2L, 2L, 3L, 2L, 
                                                                                          2L, 3L, 1L, 2L, 1L, 2L, 3L, 1L, 3L, 1L, 2L, 4L, 4L, 3L, 3L, 
                                                                                          2L, 1L, 2L, 2L, 1L, 2L, 1L, 4L, 2L, 1L, 1L, 2L, 2L, 1L, 1L, 
                                                                                          3L, 1L, 1L, 1L, 3L, 2L, 1L, 1L, 4L, 1L, 3L, 1L, 2L, 2L, 1L, 
                                                                                          1L, 1L, 3L, 1L, 1L, 2L, 1L, 1L, 1L, 2L, 1L, 1L, 1L, 2L, 2L, 
                                                                                          2L, 1L, 2L, 2L, 2L, 1L, 2L, 2L, 2L, 2L, 2L, 2L, 2L, 1L, 2L, 
                                                                                          1L, 1L, 2L, 2L, 2L, 1L, 4L, 3L, 2L, 2L, 1L, 2L, 2L, 2L, 3L, 
                                                                                          2L, 3L, 2L, 2L, 2L, 2L, 2L, 2L, 2L, 2L, 2L, 2L, 2L, 3L, 2L, 
                                                                                          1L, 2L, 2L, 2L, 2L, 1L, 3L, 1L, 1L, 1L, 2L, 1L, 1L, 1L, 1L, 
                                                                                          4L, 2L, 2L, 2L, 2L, 3L, 2L, 2L, 2L, 2L, 2L, 4L, 2L, 2L, 2L, 
                                                                                          2L, 2L, 1L, 2L, 1L, 1L, 2L, 2L, 2L, 3L, 3L, 3L, 2L, 2L, 3L, 
                                                                                          4L, 3L, 1L, 2L, 2L, 4L, 2L, 1L, 3L, 4L, 2L, 1L, 2L, 2L, 2L, 
                                                                                          2L, 3L, 3L, 2L, 3L, 2L, 2L, 2L, 3L, 3L, 3L, 2L, 4L, 3L, 3L, 
                                                                                          2L, 4L, 2L, 2L, 2L, 3L, 3L, 3L, 3L, 3L, 2L, 2L, 1L, 2L, 2L, 
                                                                                          3L, 2L, 2L, 2L, 2L, 3L, 1L, 2L, 2L, 1L, 1L, 3L, 3L, 3L, 2L, 
                                                                                          2L, 2L, 1L, 2L, 1L, 3L, 2L, 2L, 1L, 1L, 1L), schoolsup = structure(c(2L, 
                                                                                                                                                               1L, 2L, 1L, 2L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 
                                                                                                                                                               2L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 2L, 1L, 2L, 2L, 
                                                                                                                                                               1L, 1L, 2L, 1L, 1L, 2L, 1L, 1L, 1L, 1L, 2L, 1L, 2L, 2L, 2L, 
                                                                                                                                                               2L, 1L, 1L, 2L, 1L, 2L, 1L, 2L, 1L, 2L, 1L, 1L, 1L, 1L, 1L, 
                                                                                                                                                               1L, 1L, 1L, 2L, 2L, 1L, 2L, 2L, 1L, 1L, 1L, 2L, 2L, 1L, 1L, 
                                                                                                                                                               2L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 2L, 2L, 1L, 1L, 1L, 
                                                                                                                                                               1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 2L, 1L, 1L, 1L, 1L, 1L, 1L, 
                                                                                                                                                               1L, 1L, 1L, 1L, 2L, 2L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 
                                                                                                                                                               1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 
                                                                                                                                                               1L, 1L, 1L, 2L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 
                                                                                                                                                               1L, 1L, 2L, 1L, 1L, 1L, 1L, 2L, 1L, 1L, 2L, 1L, 1L, 1L, 1L, 
                                                                                                                                                               1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 
                                                                                                                                                               1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 
                                                                                                                                                               2L, 1L, 1L, 2L, 1L, 1L, 2L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 
                                                                                                                                                               1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 2L, 1L, 
                                                                                                                                                               1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 
                                                                                                                                                               1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 
                                                                                                                                                               1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 
                                                                                                                                                               1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L), .Label = c("no", 
                                                                                                                                                                                                                       "yes"), class = "factor"), famsup = structure(c(1L, 2L, 1L, 
                                                                                                                                                                                                                                                                       2L, 2L, 2L, 2L, 2L, 2L, 2L, 2L, 2L, 2L, 2L, 1L, 2L, 2L, 2L, 
                                                                                                                                                                                                                                                                       2L, 1L, 2L, 2L, 2L, 2L, 1L, 2L, 2L, 2L, 2L, 2L, 1L, 2L, 1L, 
                                                                                                                                                                                                                                                                       2L, 2L, 1L, 2L, 1L, 1L, 2L, 2L, 2L, 2L, 2L, 1L, 2L, 1L, 2L, 
                                                                                                                                                                                                                                                                       2L, 2L, 2L, 2L, 1L, 2L, 1L, 2L, 2L, 1L, 1L, 2L, 1L, 2L, 2L, 
                                                                                                                                                                                                                                                                       1L, 2L, 2L, 2L, 2L, 2L, 2L, 2L, 2L, 1L, 2L, 2L, 2L, 1L, 1L, 
                                                                                                                                                                                                                                                                       1L, 2L, 1L, 2L, 1L, 2L, 2L, 2L, 1L, 1L, 2L, 2L, 1L, 2L, 2L, 
                                                                                                                                                                                                                                                                       2L, 1L, 2L, 1L, 2L, 1L, 2L, 2L, 2L, 1L, 2L, 2L, 2L, 1L, 1L, 
                                                                                                                                                                                                                                                                       2L, 2L, 2L, 1L, 1L, 2L, 1L, 2L, 1L, 1L, 2L, 1L, 1L, 2L, 2L, 
                                                                                                                                                                                                                                                                       1L, 2L, 1L, 2L, 2L, 1L, 2L, 2L, 1L, 1L, 1L, 1L, 1L, 1L, 2L, 
                                                                                                                                                                                                                                                                       2L, 2L, 2L, 2L, 2L, 2L, 2L, 1L, 2L, 2L, 1L, 1L, 2L, 2L, 2L, 
                                                                                                                                                                                                                                                                       1L, 2L, 1L, 1L, 2L, 2L, 1L, 2L, 2L, 2L, 2L, 1L, 1L, 1L, 1L, 
                                                                                                                                                                                                                                                                       1L, 1L, 2L, 1L, 2L, 1L, 1L, 1L, 2L, 1L, 1L, 1L, 2L, 2L, 2L, 
                                                                                                                                                                                                                                                                       1L, 2L, 2L, 1L, 2L, 1L, 2L, 2L, 2L, 2L, 2L, 2L, 2L, 2L, 1L, 
                                                                                                                                                                                                                                                                       1L, 2L, 1L, 1L, 1L, 2L, 1L, 2L, 2L, 1L, 2L, 2L, 2L, 2L, 2L, 
                                                                                                                                                                                                                                                                       2L, 2L, 2L, 2L, 2L, 1L, 2L, 2L, 2L, 1L, 1L, 2L, 1L, 2L, 1L, 
                                                                                                                                                                                                                                                                       1L, 2L, 2L, 2L, 2L, 2L, 2L, 2L, 2L, 1L, 1L, 1L, 1L, 2L, 2L, 
                                                                                                                                                                                                                                                                       2L, 1L, 2L, 2L, 1L, 1L, 2L, 2L, 1L, 2L, 2L, 2L, 1L, 1L, 1L, 
                                                                                                                                                                                                                                                                       1L, 2L, 1L, 1L, 2L, 2L, 1L, 2L, 1L, 1L, 1L, 2L, 1L, 2L, 1L, 
                                                                                                                                                                                                                                                                       1L, 1L, 1L, 1L, 2L, 2L, 1L, 1L, 1L), .Label = c("no", "yes"
                                                                                                                                                                                                                                                                       ), class = "factor"), paid = structure(c(1L, 1L, 2L, 2L, 
                                                                                                                                                                                                                                                                                                                1L, 2L, 2L, 2L, 1L, 2L, 2L, 1L, 1L, 2L, 1L, 1L, 2L, 2L, 2L, 
                                                                                                                                                                                                                                                                                                                2L, 2L, 2L, 1L, 1L, 1L, 1L, 1L, 2L, 1L, 1L, 1L, 1L, 1L, 1L, 
                                                                                                                                                                                                                                                                                                                2L, 1L, 2L, 2L, 2L, 2L, 1L, 1L, 1L, 1L, 1L, 2L, 1L, 1L, 1L, 
                                                                                                                                                                                                                                                                                                                2L, 2L, 1L, 1L, 2L, 2L, 2L, 2L, 2L, 2L, 1L, 2L, 1L, 2L, 2L, 
                                                                                                                                                                                                                                                                                                                1L, 1L, 2L, 2L, 2L, 1L, 1L, 2L, 1L, 2L, 1L, 2L, 1L, 1L, 1L, 
                                                                                                                                                                                                                                                                                                                1L, 1L, 1L, 1L, 2L, 2L, 1L, 1L, 1L, 1L, 1L, 2L, 1L, 1L, 1L, 
                                                                                                                                                                                                                                                                                                                1L, 1L, 1L, 1L, 1L, 1L, 1L, 2L, 1L, 2L, 1L, 1L, 1L, 1L, 2L, 
                                                                                                                                                                                                                                                                                                                1L, 1L, 2L, 1L, 1L, 1L, 2L, 1L, 1L, 1L, 1L, 2L, 2L, 1L, 1L, 
                                                                                                                                                                                                                                                                                                                2L, 2L, 1L, 2L, 2L, 1L, 1L, 1L, 1L, 2L, 1L, 1L, 1L, 1L, 1L, 
                                                                                                                                                                                                                                                                                                                2L, 2L, 1L, 2L, 2L, 2L, 2L, 2L, 2L, 2L, 2L, 2L, 1L, 1L, 1L, 
                                                                                                                                                                                                                                                                                                                2L, 1L, 1L, 2L, 2L, 1L, 2L, 1L, 2L, 2L, 1L, 2L, 1L, 1L, 1L, 
                                                                                                                                                                                                                                                                                                                1L, 2L, 1L, 2L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 2L, 1L, 1L, 
                                                                                                                                                                                                                                                                                                                2L, 2L, 1L, 2L, 2L, 2L, 1L, 2L, 2L, 2L, 2L, 2L, 2L, 1L, 2L, 
                                                                                                                                                                                                                                                                                                                1L, 2L, 1L, 1L, 1L, 2L, 2L, 2L, 2L, 2L, 2L, 2L, 2L, 2L, 2L, 
                                                                                                                                                                                                                                                                                                                2L, 2L, 2L, 1L, 2L, 2L, 2L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 
                                                                                                                                                                                                                                                                                                                2L, 2L, 2L, 2L, 1L, 2L, 2L, 1L, 1L, 1L, 1L, 2L, 2L, 1L, 1L, 
                                                                                                                                                                                                                                                                                                                1L, 1L, 1L, 1L, 1L, 2L, 2L, 1L, 2L, 1L, 1L, 1L, 1L, 1L, 1L, 
                                                                                                                                                                                                                                                                                                                2L, 1L, 2L, 2L, 2L, 1L, 2L, 1L, 1L, 1L, 2L, 2L, 2L, 2L, 1L, 
                                                                                                                                                                                                                                                                                                                1L, 2L, 2L, 2L, 2L, 1L, 1L, 1L), .Label = c("no", "yes"), class = "factor"), 
absences = c(6L, 4L, 10L, 4L, 6L, 0L, 0L, 0L, 4L, 2L, 2L, 
             4L, 16L, 0L, 2L, 0L, 2L, 14L, 2L, 4L, 16L, 0L, 0L, 0L, 0L, 
             0L, 7L, 8L, 8L, 0L, 14L, 12L, 4L, 2L, 2L, 6L, 0L, 6L, 8L, 
             0L, 4L, 2L, 2L, 6L, 4L, 2L, 0L, 2L, 4L, 2L, 0L, 2L, 2L, 54L, 
             0L, 2L, 10L, 4L, 6L, 4L, 12L, 18L, 0L, 4L, 4L, 2L, 2L, 0L, 
             14L, 0L, 4L, 0L, 10L, 8L, 2L, 4L, 6L, 10L, 8L, 2L, 0L, 20L, 
             6L, 6L, 2L, 18L, 0L, 0L, 2L, 0L, 8L, 0L, 0L, 12L, 16L, 0L, 
             0L, 0L, 0L, 0L, 8L, 2L, 2L, 0L, 0L, 0L, 0L, 6L, 8L, 0L, 0L, 
             2L, 8L, 6L, 2L, 4L, 0L, 0L, 16L, 4L, 0L, 0L, 0L, 0L, 4L, 
             2L, 10L, 10L, 2L, 56L, 12L, 4L, 0L, 12L, 0L, 0L, 4L, 24L, 
             2L, 6L, 4L, 18L, 6L, 28L, 5L, 10L, 6L, 13L, 2L, 22L, 4L, 
             2L, 0L, 2L, 0L, 16L, 10L, 2L, 14L, 14L, 4L, 14L, 2L, 18L, 
             10L, 4L, 20L, 2L, 0L, 14L, 2L, 0L, 0L, 6L, 4L, 16L, 8L, 4L, 
             0L, 0L, 2L, 6L, 12L, 8L, 21L, 2L, 1L, 13L, 2L, 10L, 0L, 15L, 
             4L, 2L, 2L, 2L, 6L, 75L, 22L, 15L, 30L, 19L, 4L, 4L, 2L, 
             5L, 6L, 6L, 9L, 11L, 0L, 6L, 8L, 4L, 0L, 10L, 0L, 14L, 0L, 
             0L, 0L, 20L, 0L, 0L, 18L, 0L, 20L, 14L, 40L, 0L, 9L, 2L, 
             23L, 12L, 3L, 7L, 7L, 0L, 0L, 16L, 12L, 0L, 7L, 0L, 11L, 
             0L, 4L, 7L, 9L, 0L, 0L, 8L, 2L, 4L, 0L, 2L, 0L, 0L, 2L, 0L, 
             0L, 0L, 0L, 10L, 4L, 3L, 14L, 0L, 2L, 4L, 0L, 17L, 4L, 5L, 
             2L, 14L, 2L, 0L, 11L, 3L, 0L, 5L)), .Names = c("final_grade", 
                                                            "age", "address", "studytime", "schoolsup", "famsup", "paid", 
                                                            "absences"), row.names = c(1L, 2L, 3L, 5L, 8L, 9L, 10L, 11L, 
                                                                                       12L, 13L, 14L, 16L, 19L, 22L, 23L, 24L, 25L, 26L, 27L, 28L, 30L, 
                                                                                       31L, 32L, 33L, 34L, 36L, 38L, 40L, 42L, 44L, 45L, 47L, 48L, 50L, 
                                                                                       51L, 53L, 54L, 55L, 56L, 57L, 58L, 59L, 60L, 62L, 63L, 64L, 65L, 
                                                                                       66L, 67L, 69L, 71L, 73L, 74L, 75L, 78L, 81L, 83L, 84L, 86L, 88L, 
                                                                                       89L, 90L, 91L, 92L, 93L, 97L, 98L, 100L, 101L, 102L, 103L, 105L, 
                                                                                       106L, 107L, 108L, 110L, 113L, 114L, 115L, 116L, 118L, 119L, 120L, 
                                                                                       122L, 123L, 124L, 126L, 127L, 128L, 129L, 130L, 131L, 132L, 133L, 
                                                                                       134L, 136L, 137L, 138L, 140L, 141L, 142L, 143L, 144L, 146L, 147L, 
                                                                                       149L, 151L, 152L, 153L, 154L, 155L, 156L, 157L, 158L, 159L, 160L, 
                                                                                       161L, 163L, 166L, 167L, 168L, 170L, 171L, 174L, 175L, 177L, 179L, 
                                                                                       181L, 182L, 184L, 186L, 190L, 192L, 193L, 195L, 196L, 197L, 199L, 
                                                                                       201L, 202L, 203L, 204L, 205L, 206L, 207L, 208L, 209L, 212L, 216L, 
                                                                                       217L, 220L, 221L, 222L, 223L, 224L, 226L, 227L, 228L, 229L, 231L, 
                                                                                       232L, 233L, 234L, 235L, 236L, 237L, 238L, 239L, 240L, 241L, 242L, 
                                                                                       244L, 245L, 246L, 247L, 248L, 249L, 253L, 254L, 255L, 256L, 257L, 
                                                                                       258L, 259L, 261L, 262L, 263L, 266L, 267L, 269L, 270L, 271L, 272L, 
                                                                                       273L, 274L, 275L, 276L, 277L, 278L, 279L, 281L, 282L, 284L, 285L, 
                                                                                       286L, 287L, 288L, 289L, 290L, 291L, 292L, 294L, 295L, 296L, 297L, 
                                                                                       298L, 299L, 301L, 302L, 303L, 304L, 305L, 307L, 309L, 310L, 311L, 
                                                                                       312L, 315L, 316L, 317L, 318L, 320L, 321L, 322L, 323L, 329L, 332L, 
                                                                                       333L, 335L, 336L, 337L, 338L, 339L, 342L, 343L, 344L, 345L, 346L, 
                                                                                       347L, 348L, 349L, 351L, 352L, 354L, 356L, 358L, 360L, 361L, 362L, 
                                                                                       364L, 365L, 367L, 369L, 370L, 371L, 372L, 374L, 375L, 376L, 377L, 
                                                                                       379L, 380L, 381L, 382L, 383L, 385L, 386L, 389L, 391L, 392L, 394L, 
                                                                                       395L), class = "data.frame")
grade_test = structure(list(final_grade = c(8, 7, 5, 7.5, 9, 5.5, 5.5, 9, 
                                            3, 7, 3, 5, 5, 5.5, 5, 3, 7, 5, 7, 5, 7, 4, 0, 5.5, 5, 0, 8, 
                                            3, 5.5, 7.5, 6.5, 5, 5, 3.5, 7, 5, 4, 4.5, 0, 5.5, 5, 4, 5.5, 
                                            5.5, 8, 5, 7, 0, 6.5, 4, 6.5, 5, 5, 0, 3, 0), age = c(15L, 16L, 
                                                                                                  16L, 16L, 15L, 15L, 16L, 15L, 15L, 15L, 16L, 15L, 17L, 15L, 15L, 
                                                                                                  16L, 15L, 15L, 16L, 16L, 15L, 16L, 17L, 15L, 17L, 16L, 16L, 17L, 
                                                                                                  16L, 16L, 16L, 16L, 16L, 17L, 16L, 17L, 18L, 17L, 18L, 18L, 18L, 
                                                                                                  19L, 19L, 19L, 17L, 17L, 17L, 18L, 18L, 18L, 17L, 18L, 18L, 17L, 
                                                                                                  18L, 19L), address = structure(c(2L, 2L, 2L, 2L, 2L, 1L, 2L, 
                                                                                                                                   2L, 2L, 2L, 2L, 2L, 2L, 2L, 2L, 2L, 2L, 1L, 2L, 1L, 2L, 2L, 2L, 
                                                                                                                                   2L, 2L, 2L, 2L, 2L, 2L, 2L, 2L, 1L, 2L, 1L, 2L, 1L, 2L, 2L, 2L, 
                                                                                                                                   1L, 2L, 2L, 2L, 2L, 2L, 1L, 2L, 2L, 1L, 2L, 1L, 2L, 1L, 1L, 1L, 
                                                                                                                                   1L), .Label = c("R", "U"), class = "factor"), studytime = c(3L, 
                                                                                                                                                                                               3L, 1L, 1L, 3L, 3L, 2L, 2L, 2L, 2L, 4L, 4L, 1L, 3L, 2L, 2L, 4L, 
                                                                                                                                                                                               4L, 1L, 3L, 2L, 2L, 1L, 2L, 1L, 2L, 2L, 2L, 1L, 2L, 2L, 1L, 2L, 
                                                                                                                                                                                               3L, 2L, 1L, 1L, 3L, 3L, 2L, 1L, 1L, 2L, 2L, 1L, 1L, 3L, 2L, 1L, 
                                                                                                                                                                                               1L, 2L, 2L, 2L, 1L, 1L, 3L), schoolsup = structure(c(1L, 1L, 
                                                                                                                                                                                                                                                    1L, 1L, 1L, 2L, 1L, 1L, 2L, 1L, 2L, 1L, 2L, 2L, 1L, 1L, 1L, 2L, 
                                                                                                                                                                                                                                                    1L, 2L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 
                                                                                                                                                                                                                                                    2L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 1L, 
                                                                                                                                                                                                                                                    1L, 1L, 1L, 1L, 1L, 1L), .Label = c("no", "yes"), class = "factor"), 
                            famsup = structure(c(2L, 2L, 1L, 2L, 2L, 2L, 2L, 2L, 2L, 
                                                 2L, 2L, 1L, 2L, 1L, 2L, 2L, 2L, 2L, 1L, 2L, 2L, 1L, 2L, 2L, 
                                                 1L, 2L, 2L, 1L, 2L, 1L, 1L, 2L, 2L, 2L, 2L, 2L, 1L, 1L, 2L, 
                                                 1L, 1L, 2L, 1L, 2L, 1L, 2L, 2L, 1L, 2L, 1L, 2L, 2L, 2L, 2L, 
                                                 2L, 1L), .Label = c("no", "yes"), class = "factor"), paid = structure(c(1L, 
                                                                                                                         2L, 2L, 2L, 1L, 2L, 1L, 1L, 2L, 2L, 2L, 1L, 1L, 2L, 1L, 1L, 
                                                                                                                         1L, 2L, 1L, 1L, 1L, 2L, 1L, 2L, 1L, 2L, 2L, 1L, 2L, 2L, 1L, 
                                                                                                                         2L, 2L, 2L, 2L, 2L, 1L, 1L, 2L, 2L, 2L, 2L, 1L, 2L, 1L, 1L, 
                                                                                                                         2L, 1L, 1L, 1L, 2L, 1L, 2L, 2L, 2L, 1L), .Label = c("no", 
                                                                                                                                                                             "yes"), class = "factor"), absences = c(0L, 6L, 4L, 0L, 2L, 
                                                                                                                                                                                                                     2L, 25L, 2L, 8L, 2L, 4L, 0L, 2L, 4L, 2L, 4L, 6L, 2L, 6L, 
                                                                                                                                                                                                                     0L, 2L, 0L, 0L, 2L, 2L, 0L, 2L, 4L, 2L, 0L, 10L, 8L, 0L, 
                                                                                                                                                                                                                     6L, 0L, 12L, 0L, 4L, 0L, 8L, 8L, 38L, 3L, 22L, 3L, 8L, 4L, 
                                                                                                                                                                                                                     0L, 10L, 7L, 4L, 0L, 4L, 0L, 7L, 0L)), .Names = c("final_grade", 
                                                                                                                                                                                                                                                                       "age", "address", "studytime", "schoolsup", "famsup", "paid", 
                                                                                                                                                                                                                                                                       "absences"), row.names = c(15L, 17L, 20L, 35L, 37L, 39L, 41L, 
                                                                                                                                                                                                                                                                                                  43L, 46L, 49L, 68L, 72L, 79L, 82L, 85L, 87L, 95L, 96L, 99L, 112L, 
                                                                                                                                                                                                                                                                                                  117L, 125L, 145L, 148L, 164L, 169L, 172L, 178L, 187L, 188L, 191L, 
                                                                                                                                                                                                                                                                                                  198L, 200L, 210L, 213L, 215L, 251L, 264L, 265L, 268L, 280L, 308L, 
                                                                                                                                                                                                                                                                                                  313L, 314L, 327L, 328L, 330L, 334L, 350L, 353L, 357L, 363L, 366L, 
                                                                                                                                                                                                                                                                                                  368L, 387L, 388L), class = "data.frame")



######
grade_train3 = grade_train
grade_train3$final_grade <- (grade_train$final_grade == 0)
mod_aux = glm(final_grade ~ ., family = binomial(), data = grade_train3)

##########

pred1 = predict(mod_aux, grade_test, type = "response")
actu1 = (grade_test$final_grade == 0)
pred2 = ifelse(pred1 > 0.5 , 1, 0)
table(actu1, pred2)
rmse(actu1, pred2)

##############




pred1 = predict(mod_aux, grade_train, type = "response")

grade_train_enhanced = cbind(grade_train, pred1)
grade_train_enhanced$final_grade = ifelse(grade_train_enhanced$final_grade == 0, 0.25, grade_train$final_grade)

mod_fato = glm(final_grade ~ ., family = Gamma(link = "log"), data = grade_train_enhanced)

pred1 = predict(mod_aux, grade_test, type = "response")

grade_test_enhanced = cbind(grade_test, pred1)

predtest = predict(mod_fato, grade_test_enhanced, type = "response")

rmse(grade_test$final_grade, predtest)

#### ÁRVORE


grade_train3 = grade_train
grade_train3$final_grade <- (grade_train$final_grade == 0)
mod_aux_tree = rpart(formula = final_grade ~ ., data = grade_train3, method = "class")
pred_aux = predict(mod_aux_tree)
pred_aux = pred_aux[,"TRUE"]

grade_train_enhanced_tree = cbind(grade_train, pred_aux)

mod_fato = rpart(formula = final_grade ~ ., data = grade_train_enhanced_tree, method = "anova")

pred_test_aux = predict(mod_aux_tree, grade_test)

pred_aux = pred_test_aux[,"TRUE"]

grade_test_enhanced_tree = cbind(grade_test, pred_aux)

predtest_tree = predict(mod_fato, grade_test_enhanced_tree)

rmse(grade_test$final_grade, predtest_tree)

####
library(betareg)
######
grade_train3 = grade_train
grade_train3$final_grade <- (grade_train$final_grade == 0)
mod_aux = glm(final_grade ~ ., family = binomial(), data = grade_train3)
pred1 = predict(mod_aux, grade_train, type = "response")

grade_train_enhanced = cbind(grade_train, pred1)
grade_train_enhanced$final_grade = ifelse(grade_train_enhanced$final_grade == 0, 0.25, grade_train$final_grade)
grade_train_enhanced$final_grade = ifelse(grade_train_enhanced$final_grade == 10, 9.75, grade_train_enhanced$final_grade)

grade_train_enhanced$final_grade = grade_train_enhanced$final_grade/10

mod_fato = betareg(final_grade ~ ., data = grade_train_enhanced)

pred1 = predict(mod_aux, grade_test, type = "response")

grade_test_enhanced = cbind(grade_test, pred1)

predtest = 10*predict(mod_fato, grade_test_enhanced, type = "response")

rmse(grade_test$final_grade, predtest)




library(ipred)


bagged_model = bagging(final_grade ~ ., data = grade_train, coob = TRUE, control=
                         rpart.control(minsplit = 2, cp = 0.01, xval = 10,maxdepth = 1))
pred = predict(bagged_model, grade_test)
rmse(pred, grade_test$final_grade)


########
library(ranger)

RF_model = ranger(final_grade ~ ., data = grade_train, num.trees = 1000)
pred = predict(RF_model, grade_test)
rmse(pred$predictions, grade_test$final_grade)


# Establish a list of possible values for mtry, nodesize and sampsize
mtry <- seq(4, ncol(grade_train) * 0.8, 2)
nodesize <- seq(3, 8, 2)
sampsize <- c(0.7, 0.8)

# Create a data frame containing all combinations 
hyper_grid <- expand.grid(mtry = mtry, nodesize = nodesize, sampsize = sampsize)

# Create an empty vector to store OOB error values
oob_err <- c()

# Write a loop over the rows of hyper_grid to train the grid of models
for (i in 1:nrow(hyper_grid)) {
  
  # Train a Random Forest model
  model <- ranger(formula = final_grade ~ ., 
                        data = grade_train,
                        mtry = hyper_grid$mtry[i],
                        min.node.size = hyper_grid$nodesize[i],
                        sample.fraction = hyper_grid$sampsize[i])
  pred = predict(model, grade_test)
  oob_err[i] <- rmse(pred$predictions, grade_test$final_grade)
  
  # Store OOB error for the model                      
  # oob_err[i] <- model$prediction.error
}

# Identify optimal set of hyperparmeters based on OOB error
opt_i <- which.min(oob_err)
print(hyper_grid[opt_i,])

RF_model <- ranger(formula = final_grade ~ ., 
                data = grade_train,
                mtry = 4,
                min.node.size = 7,
                sample.fraction = 0.7)

pred = predict(RF_model, grade_test)
rmse(pred$predictions, grade_test$final_grade)


library(gbm)

gbm_model = gbm(formula = final_grade ~ ., data = grade_train, distribution = "gaussian", n.trees = 1000, cv.folds = 3)
pred = predict(gbm_model, grade_test, type = "response", n.trees = 53)
rmse(pred, grade_test$final_grade)

ntree_opt_oob <- gbm.perf(object = gbm_model, 
                          method = "cv")







#################

library(e1071)


grade_train3 = grade_train
grade_train3$final_grade <- (grade_train$final_grade == 0)

tune_out <- tune.svm(final_grade ~ ., data = grade_train3, gamma = 5*10^(-2:2), cost = c(0.1, 1, 10, 100), type = "C-classification", kernel = "radial")
mod_aux = svm(final_grade ~ ., data = grade_train3, type = "C-classification", kernel = "radial", gamma = tune_out$best.parameters$gamma, cost = tune_out$best.parameters$cost, scale = FALSE)

pred1 = predict(mod_aux, grade_train, type = "response")

grade_train_enhanced = cbind(grade_train, pred1)


gbm_model = gbm(formula = final_grade ~ ., data = grade_train_enhanced, distribution = "gaussian", n.trees = 1000)

pred1 = predict(mod_aux, grade_test, type = "response")

grade_test_enhanced = cbind(grade_test, pred1)


pred = predict(gbm_model, grade_test_enhanced, type = "response", n.trees = 1000)
rmse(pred, grade_test$final_grade)
# Out:
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
#        pred2
# actu1    0  1
#   FALSE 48  2
#   TRUE   4  2
# [1] 0.3273268
# [1] 2.055669
# [1] 2.372489
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# [1] 2.023176
# [1] 2.128597
# [1] 2.147407
#   mtry nodesize sampsize
# 5    4        7      0.7
# [1] 2.126655
# Loaded gbm 2.1.5
# [1] 2.068084
# [1] 2.383992
# plot without title

# %%
library(gbm)

gbm_model = gbm(formula = final_grade ~ ., data = grade_train, distribution = "gaussian", n.trees = 1000, cv.folds = 3)
pred = predict(gbm_model, grade_test, type = "response", n.trees = 53)
rmse(pred, grade_test$final_grade)

ntree_opt_oob <- gbm.perf(object = gbm_model, 
                          method = "cv")
# Out:
# [1] 2.088442
# plot without title

# %%
ntree_opt_oob
# Out:
# [1] 93

# %%
grade_train3 = grade_train
grade_train3$final_grade <- (grade_train$final_grade == 0)

tune_out <- tune.svm(final_grade ~ ., data = grade_train3, gamma = 5*10^(-2:2), cost = c(0.1, 1, 10, 100), type = "C-classification", kernel = "radial")
mod_aux = svm(final_grade ~ ., data = grade_train3, type = "C-classification", kernel = "radial", gamma = tune_out$best.parameters$gamma, cost = tune_out$best.parameters$cost, scale = FALSE)

pred1 = predict(mod_aux, grade_train, type = "response")

grade_train_enhanced = cbind(grade_train, pred1)


gbm_model = gbm(formula = final_grade ~ ., data = grade_train_enhanced, distribution = "gaussian", n.trees = 1000)

pred1 = predict(mod_aux, grade_test, type = "response")

grade_test_enhanced = cbind(grade_test, pred1)


pred = predict(gbm_model, grade_test_enhanced, type = "response", n.trees = 1000)
rmse(pred, grade_test$final_grade)
# Out:
# [1] 2.389082

# %%
######
grade_train3 = grade_train
grade_train3$final_grade <- (grade_train$final_grade == 0)
mod_aux = glm(final_grade ~ ., family = binomial(), data = grade_train3)

##########

pred1 = predict(mod_aux, grade_test, type = "response")
actu1 = (grade_test$final_grade == 0)
pred2 = ifelse(pred1 > 0.5 , 1, 0)
table(actu1, pred2)
rmse(actu1, pred2)

##############




pred1 = predict(mod_aux, grade_train, type = "response")

grade_train_enhanced = cbind(grade_train, pred1)
grade_train_enhanced$final_grade = ifelse(grade_train_enhanced$final_grade == 0, 0.25, grade_train$final_grade)

mod_fato = glm(final_grade ~ ., family = Gamma(link = "log"), data = grade_train_enhanced)

pred1 = predict(mod_aux, grade_test, type = "response")

grade_test_enhanced = cbind(grade_test, pred1)

predtest = predict(mod_fato, grade_test_enhanced, type = "response")

rmse(grade_test$final_grade, predtest)
# Out:
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
#        pred2
# actu1    0  1
#   FALSE 48  2
#   TRUE   4  2
# [1] 0.3273268
# [1] 2.055669

# %%
####
library(betareg)
######
grade_train3 = grade_train
grade_train3$final_grade <- (grade_train$final_grade == 0)
mod_aux = glm(final_grade ~ ., family = binomial(), data = grade_train3)
pred1 = predict(mod_aux, grade_train, type = "response")



grade_train_enhanced = cbind(grade_train, pred1)
grade_train_enhanced$final_grade = ifelse(grade_train_enhanced$final_grade == 0, 0.25, grade_train$final_grade)
grade_train_enhanced$final_grade = ifelse(grade_train_enhanced$final_grade == 10, 9.75, grade_train_enhanced$final_grade)

grade_train_enhanced$final_grade = grade_train_enhanced$final_grade/10

mod_fato = betareg(final_grade ~ ., data = grade_train_enhanced)

pred1 = predict(mod_aux, grade_test, type = "response")

grade_test_enhanced = cbind(grade_test, pred1)

predtest = 10*predict(mod_fato, grade_test_enhanced, type = "response")

rmse(grade_test$final_grade, predtest)

summary(mod_fato)
# Out:
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# [1] 2.023176
# Call:
# betareg(formula = final_grade ~ ., data = grade_train_enhanced)
#
# Standardized weighted residuals 2:
#     Min      1Q  Median      3Q     Max
# -3.3395 -0.4939 -0.0216  0.5117  3.3516
#
# Coefficients (mean model with logit link):
#               Estimate Std. Error z value Pr(>|z|)
# (Intercept)   1.355383   0.754797   1.796  0.07254 .
# age          -0.074410   0.043978  -1.692  0.09065 .
# addressU      0.142719   0.128695   1.109  0.26744
# studytime     0.135049   0.066345   2.036  0.04180 *
# schoolsupyes -0.468284   0.157195  -2.979  0.00289 **
# famsupyes    -0.112312   0.113377  -0.991  0.32188
# paidyes      -0.038699   0.117705  -0.329  0.74232
# absences     -0.008679   0.006524  -1.330  0.18344
# pred1        -2.843619   0.316536  -8.984  < 2e-16 ***
#
# Phi coefficients (precision model with identity link):
#       Estimate Std. Error z value Pr(>|z|)
# ...

# %%
grade_train$schoolsup
# Out:
#   [1] yes no  yes no  yes no  no  no  no  no  no  no  no  no  no  no  yes no
#  [19] no  no  no  no  no  no  no  no  no  yes no  yes yes no  no  yes no  no
#  [37] yes no  no  no  no  yes no  yes yes yes yes no  no  yes no  yes no  yes
#  [55] no  yes no  no  no  no  no  no  no  no  yes yes no  yes yes no  no  no
#  [73] yes yes no  no  yes no  no  no  no  no  no  no  no  no  yes yes no  no
#  [91] no  no  no  no  no  no  no  no  no  yes no  no  no  no  no  no  no  no
# [109] no  no  yes yes no  no  no  no  no  no  no  no  no  no  no  no  no  no
# [127] no  no  no  no  no  no  no  no  no  no  no  no  no  yes no  no  no  no
# [145] no  no  no  no  no  no  no  no  no  yes no  no  no  no  yes no  no  yes
# [163] no  no  no  no  no  no  no  no  no  no  no  no  no  no  no  no  no  no
# [181] no  no  no  no  no  no  no  no  no  no  no  no  no  no  no  no  yes no
# [199] no  yes no  no  yes no  no  no  no  no  no  no  no  no  no  no  no  no
# ...
